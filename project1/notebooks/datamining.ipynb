# %%
import pandas as pd 

df = pd.read_csv("../../datasets/cat_in_the_dat/train_folds.csv")
df.kfold.value_counts()
# Out:
# 4    120000
# 3    120000
# 2    120000
# 1    120000
# 0    120000
# Name: kfold, dtype: int64

# %%
import seaborn as sns 

sns.countplot(data=df, x="kfold", hue="target")
